# %%
DATA ANAYSIS LEVEL-1

# %%
TASK-1:TOP CUISINES

# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Divya\OneDrive\Documents\Dataset  (2).csv")

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
cuisine_counts = data['Cuisines'].value_counts()
sorted_cuisines = cuisine_counts.sort_values(ascending=False)
total_restaurants = len(data)
top_three_cuisines = sorted_cuisines.head(3)
top_cuisines_percentage = (top_three_cuisines / total_restaurants) * 100

# %%
print("Top three most common cuisines in the dataset:")
print(top_three_cuisines)
# Out:
# Top three most common cuisines in the dataset:
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Name: count, dtype: int64

# %%
print("\nPercentage of restaurants serving each of the top cuisines:")
for cuisine, count in top_cuisines_percentage.items():
    print(f"{cuisine}: {count:.2f}%")
# Out:
# Percentage of restaurants serving each of the top cuisines:
# North Indian: 9.80%
# North Indian, Chinese: 5.35%
# Chinese: 3.71%

# %%
TASK-2:CITY ANALYSIS

# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Divya\OneDrive\Documents\Dataset  (2).csv")

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
city_restaurant_counts = data['City'].value_counts()
city_with_highest_restaurants = city_restaurant_counts.idxmax()

print(f"The city with the highest number of restaurants is: {city_with_highest_restaurants}")
# Out:
# The city with the highest number of restaurants is: New Delhi

# %%
city_avg_ratings = data.groupby('City')['Aggregate rating'].mean()

print("Average ratings for restaurants in each city:")
print(city_avg_ratings)
# Out:
# Average ratings for restaurants in each city:
# City
# Abu Dhabi          4.300000
# Agra               3.965000
# Ahmedabad          4.161905
# Albany             3.555000
# Allahabad          3.395000
#                      ...
# Weirton            3.900000
# Wellington City    4.250000
# Winchester Bay     3.200000
# Yorkton            3.300000
# ��stanbul          4.292857
# Name: Aggregate rating, Length: 141, dtype: float64

# %%
city_with_highest_avg_rating = city_avg_ratings.idxmax()

print(f"The city with the highest average rating is: {city_with_highest_avg_rating}")
# Out:
# The city with the highest average rating is: Inner City

# %%
TASK-3:Price Range Distribution

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\Divya\OneDrive\Documents\Dataset  (2).csv")

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
plt.figure(figsize=(10, 6))
data['Price range'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Distribution of Price Ranges Among Restaurants')
plt.xlabel('Price Range')
plt.ylabel('Percentage of Restaurants')
plt.xticks(rotation=0)
plt.tight_layout() 
plt.show()

# %%
total_restaurants = len(data)
price_range_counts = data['Price range'].value_counts()
percentage_per_price_range = (price_range_counts / total_restaurants) * 100
print("Percentage of restaurants in each price range category:")
print(percentage_per_price_range)
# Out:
# Percentage of restaurants in each price range category:
# Price range
# 1    46.529159
# 2    32.593446
# 3    14.741912
# 4     6.135483
# Name: count, dtype: float64

# %%
TASK-4:ONLINE DELIVERY

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\Divya\OneDrive\Documents\Dataset  (2).csv")

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
total_restaurants = len(data)
restaurants_with_delivery = data[data['Has Online delivery'] == 'Yes']
restaurants_with_delivery_count = len(restaurants_with_delivery)
percentage_with_delivery = (restaurants_with_delivery_count / total_restaurants) * 100

print("Percentage of restaurants that offer online delivery:", percentage_with_delivery)
# Out:
# Percentage of restaurants that offer online delivery: 25.662234321013504

# %%
average_rating_with_delivery = restaurants_with_delivery['Aggregate rating'].mean()

restaurants_without_delivery = data[data['Has Online delivery'] == 'No']
average_rating_without_delivery = restaurants_without_delivery['Aggregate rating'].mean()

print("Average rating of restaurants with delivery:", average_rating_with_delivery)
print("Average rating of restaurants without delivery:", average_rating_without_delivery)
# Out:
# Average rating of restaurants with delivery: 3.2488372093023257
# Average rating of restaurants without delivery: 2.465295774647887
